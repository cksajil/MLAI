# %%
print("Hello")
# Out:
# Hello

# %%
name = "Sajil"
print("Hello {}, welcome to the class".format(name))
# Out:
# Hello Sajil, welcome to the class

# %%
name = "Sajil"
class_name= "Data Science"
print("Hello {}, welcome to the {} class".format(name, class_name))
# Out:
# Hello Sajil, welcome to the Data Science class

# %%
name = "Sajil"
class_name= "Data Science"
print("Hello {1}, welcome to the {0} class".format(name, class_name))
# Out:
# Hello Data Science, welcome to the Sajil class

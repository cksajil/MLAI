# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression

# %%
X, y = load_iris(return_X_y=True)
lr_clf = LogisticRegression(random_state=0, max_iter=1000)

# %%
lr_clf.fit(X, y)
# Out:
# LogisticRegression(max_iter=1000, random_state=0)

# %%
print(lr_clf.predict(X[:2, :]))
print(lr_clf.predict_proba(X[:2, :]))
print(lr_clf.score(X, y))
# Out:
# [0 0]
# [[9.81557202e-01 1.84427831e-02 1.44809203e-08]
#  [9.71331260e-01 2.86687094e-02 3.01371913e-08]]
# 0.9733333333333334

# %%
lr_clf.classes_
# Out:
# array([0, 1, 2])

# %%
lr_clf.coef_
# Out:
# array([[-0.42415938,  0.96633485, -2.5160372 , -1.08205245],
#        [ 0.53464109, -0.32039706, -0.20702001, -0.94324899],
#        [-0.11048172, -0.64593779,  2.72305721,  2.02530144]])

# %%
lr_clf.n_features_in_
# Out:
# 4

# %% [markdown]
# ## Linear Regression

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
# y = 1 * x_0 + 2 * x_1 + 3
y = np.dot(X, np.array([1, 2])) + 3

# %%
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
print(reg.predict(np.array([[3, 5]])))
# Out:
# [1. 2.]
# 3.0000000000000018
# [16.]

# %%
y_pred = reg.predict(X)
print(mean_squared_error(y, y_pred))
# Out:
# 1.9721522630525295e-31

# %% [markdown]
# ### Q1. Write custom functions for accuracy and mean square error using numpy and compare yourresult with sklearn metric module functions

# %% [markdown]
# ## Preprocessing

# %%
data = np.array([[1],[2],[3],[4],[5]])
from sklearn.preprocessing import MinMaxScaler, StandardScaler

scaler = MinMaxScaler()
std_scaler = StandardScaler()

scaler.fit(data)
std_scaler.fit(data)

print(scaler.transform(data))
print(std_scaler.transform(data))
# Out:
# [[0.  ]
#  [0.25]
#  [0.5 ]
#  [0.75]
#  [1.  ]]
# [[-1.41421356]
#  [-0.70710678]
#  [ 0.        ]
#  [ 0.70710678]
#  [ 1.41421356]]

# %% [markdown]
# ### Q2. Impliment a custom min-max scaler and standard scaler functions and compare the output with respective sklearn library functions

# %% [markdown]
# ## Q3. Impliment a custom library with following modules and functionalities
# ```yaml
# Custom Library Modules
# ├── preprocessing
# │   ├── MinMaxScaler
# │   ├── StandardScaler
# ├── metrics
# │   ├── accuracy_score
# │   ├── mean_squared_error
# │   ├── mean_absolute_error
# │   └── mean_absolute_percentage_error
# ├── model_selection
# │   ├── train_test_split
# ```

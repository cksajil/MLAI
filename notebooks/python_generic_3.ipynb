# %%
text = ["Zero","One", "Two","Three"]
num = 321
for digit in str(num):
  print(text[(int(digit))], end=" ")
# Out:
# Three Two One

# %%
date = "30 May 2025"
day, month, year = date.split(" ")

# %%
print(day, month, year)
# Out:
# 30 May 2025

# %%
print(" ".join([day, month, year]))
# Out:
# 30 May 2025

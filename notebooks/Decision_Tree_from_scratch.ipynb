# %%
import numpy as np
import pandas as pd

# %%
data = {'Outlook': ['Sunny', 'Sunny', 'Overcast', 'Rain', 'Rain', 'Rain', 'Overcast', 'Sunny', 'Sunny', 'Rain', 'Sunny', 'Overcast', 'Overcast', 'Rain'],
        'Temperature': ['Hot', 'Hot', 'Hot', 'Mild', 'Cool', 'Cool', 'Cool', 'Mild', 'Cool', 'Mild', 'Mild', 'Mild', 'Hot', 'Mild'],
        'Humidity': ['High', 'High', 'High', 'High', 'Normal', 'Normal', 'Normal', 'High', 'Normal', 'Normal', 'Normal', 'High', 'Normal', 'High'],
        'Wind': ['Weak', 'Strong', 'Weak', 'Weak', 'Weak', 'Strong', 'Strong', 'Weak', 'Weak', 'Weak', 'Strong', 'Strong', 'Weak', 'Strong'],
        'PlayTennis': ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']}
df = pd.DataFrame(data)

df
# Out:
#      Outlook Temperature Humidity    Wind PlayTennis
# 0      Sunny         Hot     High    Weak         No
# 1      Sunny         Hot     High  Strong         No
# 2   Overcast         Hot     High    Weak        Yes
# 3       Rain        Mild     High    Weak        Yes
# 4       Rain        Cool   Normal    Weak        Yes
# 5       Rain        Cool   Normal  Strong         No
# 6   Overcast        Cool   Normal  Strong        Yes
# 7      Sunny        Mild     High    Weak         No
# 8      Sunny        Cool   Normal    Weak        Yes
# 9       Rain        Mild   Normal    Weak        Yes
# 10     Sunny        Mild   Normal  Strong        Yes
# 11  Overcast        Mild     High  Strong        Yes
# 12  Overcast         Hot   Normal    Weak        Yes
# 13      Rain        Mild     High  Strong         No

# %%
cols = df.columns.tolist()

# %%
print(cols[:-1])
# Out:
# ['Outlook', 'Temperature', 'Humidity', 'Wind']

# %%
root_node_counts = df['PlayTennis'].value_counts().values
root_entropy = compute_entropy(root_node_counts)
print(root_entropy)
# Out:
# 0.9402859586706311

# %%
def compute_entropy(x):
  x = x/np.sum(x)
  return -np.sum(x*np.log2(x))

# %%
for col in cols[:-1]:
  segments = [col, 'PlayTennis']
  print(col)
  print(df[segments])

  # values = list(set(df[col].values))
  # entropy = 0
  # for value in values:
  #   chances = df[df[col]==value]['PlayTennis'].value_counts()
  #   prob = chances/chances.sum()
  #   entropy = entropy+compute_entropy(prob.values)
  # print(value, entropy)
# Out:
# Outlook
#      Outlook PlayTennis
# 0      Sunny         No
# 1      Sunny         No
# 2   Overcast        Yes
# 3       Rain        Yes
# 4       Rain        Yes
# 5       Rain         No
# 6   Overcast        Yes
# 7      Sunny         No
# 8      Sunny        Yes
# 9       Rain        Yes
# 10     Sunny        Yes
# 11  Overcast        Yes
# 12  Overcast        Yes
# 13      Rain         No
# Temperature
#    Temperature PlayTennis
# 0          Hot         No
# 1          Hot         No
# 2          Hot        Yes
# 3         Mild        Yes
# 4         Cool        Yes
# 5         Cool         No
# 6         Cool        Yes
# 7         Mild         No
# 8         Cool        Yes
# 9         Mild        Yes
# 10        Mild        Yes
# 11        Mild        Yes
# 12         Hot        Yes
# 13        Mild         No
# Humidity
#    Humidity PlayTennis
# 0      High         No
# 1      High         No
# 2      High        Yes
# 3      High        Yes
# 4    Normal        Yes
# ...

# %%
outlook = np.array([5,4,5])
entropy_outlook = compute_entropy(outlook)

temp = np.array([4,6,4])
entropy_temp = compute_entropy(temp)

humidity= np.array([7, 7])
entropy_humidity = compute_entropy(humidity)

windy = np.array([6, 87])
entropy_windy = compute_entropy(windy)


print(entropy_outlook)
print(entropy_temp)
print(entropy_humidity)
print(entropy_windy)
# Out:
# 1.5774062828523454
# 1.5566567074628228
# 1.0
# 0.345117314944953
